# %%
import os; os.chdir(
    '..'
)

# %%
import pandas as pd

# %%
df= pd.read_csv(
    'product_categories_parent/Apparel.csv'
)

# %%
df.sample(50)
# Out:
#                               keywords
# 150                         balenciaga
# 193                      cle guardians
# 895                    basketball shoe
# 899  basketball shoes basketball shoes
# 925            burlington coat company
# 672                      ray-ban brand
# 896                    piercing on ear
# 267                        lane bryant
# 857                  polo lauren ralph
# 892          sunglasses hut sunglasses
# 399                         gowns prom
# 616              apparel store near me
# 949                         bags totes
# 12                   rack of nordstrom
# 831             jewelry stores.near me
# 453                jordan air jordan 1
# 952                            primark
# 380                         ann taylor
# 955                     dr air martens
# 435                       dry cleaners
# 421              dry cleaners cleaners
# 370                     prompt dresses
# 601              outlet bargain market
# ...
